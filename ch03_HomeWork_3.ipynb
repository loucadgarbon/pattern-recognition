# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tks = yf.Tickers(['AAPL', 'MSFT', 'GOOG', '2222.SR', 'AMZN', 'TSLA', 'FB', 'NVDA', 'BRK-A', 'TSM'])
tks
# Out:
# yfinance.Tickers object <AAPL,MSFT,GOOG,2222.SR,AMZN,TSLA,FB,NVDA,BRK-A,TSM>

# %%
tkPrice = tks.history(period='5y')
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
res = tkPrice.Close.plot(logy=True)

# %%
fig = plt.figure(figsize=(15,20))
ax = fig.gca()
res = tkPrice.Close.hist(orientation= 'horizontal', ax=ax)
# Out:
# C:\Users\VLSI-PC\AppData\Local\Temp/ipykernel_12884/2717702990.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   res = tkPrice.Close.hist(orientation= 'horizontal', ax=ax)
